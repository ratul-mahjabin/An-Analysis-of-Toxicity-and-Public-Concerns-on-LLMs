# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")

#restart runtime and continue execution from cell below
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install contractions
# !pip install demoji
import spacy
import spacy.cli
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 2.3 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 517.6 kB/s eta 0:00:00
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0

# %%
import re
import string
import pandas as pd
from pathlib import Path
from collections import defaultdict

import nltk
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
import re
import regex
import string
import unicodedata
import contractions
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

import locale
locale.getpreferredencoding = lambda: "UTF-8"
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def tokenize_ngram(text):
  if isinstance(text, str) and len(text) > 0:
    text = text.replace("front end", "frontend").replace("back end", "backend")
    toks = word_tokenize(text)
    unigrams_ls, bigrams_ls, new_toks = [], [], []
    for tok in toks:
      # split sentence by punctuation or stopword
      if tok[0].isalpha() and tok not in stopwords.words('english'):
        # remove punctuation within word
        tok = re.sub('[%s]' % re.escape(string.punctuation), '', tok)
        new_toks.append(tok)
      else: # extract ngrams of split sentence
        if len(new_toks) > 0:
          unigrams_ls += new_toks
          bigrams_ls += [" ".join(ngram) for ngram in nltk.ngrams(new_toks, 2, pad_left=True, pad_right=True, left_pad_symbol='<s>', right_pad_symbol='</s>')]
          new_toks = []
    # extract ngrams of the rest of sentence
    if len(new_toks) > 0:
      unigrams_ls += new_toks
      bigrams_ls += [" ".join(ngram) for ngram in nltk.ngrams(new_toks, 2, pad_left=True, pad_right=True, left_pad_symbol='<s>', right_pad_symbol='</s>')]
      new_toks = []

    # return unigrams and bigrams separated by " || "
    # each separated by " | "
    ngrams_ls = []
    if len(unigrams_ls) == 0 and len(bigrams_ls) == 0:
      return None
    for grams in [unigrams_ls, bigrams_ls]:
      if len(grams) != 0:
        ngrams_ls.append(" | ".join(grams))
    return " || ".join(ngrams_ls)#, ngrams_ls
  else:
    return None

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# title to occupation csv

#major occupations
mainTitle = {11:'Management',
13:'Business and Financial Ops',
15:'Computer and Mathematical',
17:'Architecture and Engineering',
19:'Life, Physical, and Social Science',
21:'Community and Social Service',
23:'Legal Occupations',
25:'Educational Instruction and Library',
27:'Arts, Design, Entertainment, Sports, and Media',
29:'Healthcare Practitioners and Technical',
31:'Healthcare Support',
33:'Protective Service',
35:'Food Preparation and Serving Related',
37:'Building and Grounds Cleaning and Maintenance',
39:'Personal Care and Service',
41:'Sales and Related',
43:'Office and Administrative Support',
45:'Farming, Fishing, and Forestry',
47:'Construction and Extraction',
49:'Installation, Maintenance, and Repair',
51:'Production',
53:'Transportation and Material Moving',
55:'Military Specific'}
data_dir = "/content/drive/MyDrive/SMM"
title2occupation_df = pd.read_csv(Path(data_dir, 'title_file.csv'), encoding='unicode_escape',).drop_duplicates()
title2occupation_df = title2occupation_df.drop_duplicates()
soc_occupation = []
# Map codes to Occupations
for index, row in title2occupation_df.iterrows():
    code = row['2018 SOC Code'][:2]
    soc_occupation.append(mainTitle[int(code)])

title2occupation_df = title2occupation_df.assign(Occupation=soc_occupation)
title2occupation_df = title2occupation_df.rename(columns={"2018 SOC Title": "Title"})

title2occupation_df = title2occupation_df.drop(columns=['2018 SOC Code','2018 SOC Direct Match Title', 'Illustrative Example'])
title2occupation_df = title2occupation_df.drop_duplicates()
title2occupation_df['Title'] = title2occupation_df['Title'].str.lower()

#lemmatize titles
nlp = spacy.load("en_core_web_lg")
lemmas = []
for doc in nlp.pipe(title2occupation_df["Title"].fillna('')):
  lemmas.append(" ".join(token.lemma_ for token in doc))
title2occupation_df["Title"] = lemmas
title2occupation_df.head()
title2occupation_df.to_csv(Path(data_dir, 'title2OccupationNew.csv'), index=False)

# %%
# load curated lists

# title to occupation dictionary
title2occu_df = pd.read_csv(Path(data_dir, 'title2OccupationNew.csv'), encoding='unicode_escape',).drop_duplicates()
def tokenize_titles(title,occupation):
  title = re.sub('[^A-Za-z]+', ' ', title)
  title = ' '.join(word.lower() for word in title.split() if word.lower() not in stopwords.words('english'))
  words = title.split()
  # print(words)
  tups = []
  # title2Occ_dict = {}
  for word in words:
    # title2Occ_dict[word] = occupation
    x = (word, occupation)
    tups.append(x)
  # print(tups)
  return tups
# print(tups)
# tupList = []
title2Occ_temp = title2occu_df.apply(lambda row: tokenize_titles(row['Title'],row['Occupation']),axis =1)
titleList = []
for tupList in title2Occ_temp:
  for tup in tupList:
    titleList.append(tup)
# print(titleList)
title2occupation_df  = pd.DataFrame(titleList, columns = ['Title','Occupation'])
# title2occupation_df.head()


# titles belong to multiple occupation groups are ambiguous
ambiguous = set(title2occupation_df[title2occupation_df.Title.duplicated()].Title.tolist())
unambiguous = set(title2occupation_df.Title.tolist()) - ambiguous
# print(ambiguous)

# each ambiguous titles have a default fallback occupation value,
# in case disambiguation doesnot work
title2occupation_df = title2occupation_df.drop_duplicates(subset=['Title'])
title2occupation_dict = pd.Series(title2occupation_df.Occupation.values, index=title2occupation_df.Title).to_dict()
soc_set_title = list(title2occupation_dict.keys())
assert (unambiguous | ambiguous) == set(soc_set_title)

# modifier2occupation
modifier2occupation = pd.read_csv(Path(data_dir, 'modifier2occupation.csv'))
modifier2occupation = dict(zip(list(modifier2occupation.modifier),list(modifier2occupation.occupation)))

# keyword2occupation
keyword2occupation = pd.read_csv(Path(data_dir, 'keyword2occupation.csv'))
keyword2occupation = dict(zip(list(keyword2occupation.keyword),list(keyword2occupation.occupation)))

# %%
def disambiguate(modifier):
  try:
    return modifier2occupation[modifier]
  except KeyError:
    return None

def match_keyword(keyword):
  try:
    return keyword2occupation[keyword]
  except KeyError:
    return None

def extract_occupation(text):
  # print(text)
  if isinstance(text, str):
    unigrams, bigrams = text.split(" || ")
  else:
    return None

  # return first matched title from bigrams and unigrams
  bigrams = bigrams.split(" | ")
  bigrams = [s.split() for s in bigrams]
  for ngram in bigrams:
    # unambiguous title in either position
    for gram in ngram:
      if gram in unambiguous: # 1st position
        assert isinstance(title2occupation_dict[gram], str)
        print(f"unambiguous: {gram} in {ngram}")
        return (' '.join(ngram), title2occupation_dict[gram])
    # ambiguous title @ 2nd position disambiguate by 1st position
    if ngram[1] in ambiguous:
      # print(ngram[0])
      match = disambiguate(ngram[0])
      # print(f"match: {match}")
      if match is not None: # disambiguate success
        assert isinstance(match, str)
        print(f"ambiguous @ 2nd: {ngram[1]} in {ngram}")
        return (' '.join(ngram), match)
    # return ambiguous title @ 1st position, return default occupation
    if ngram[0] in ambiguous:
      assert isinstance(title2occupation_dict[ngram[0]], str)
      print(f"ambiguous @ 1st: {ngram[0]} in {ngram}")
      return (' '.join(ngram), title2occupation_dict[ngram[0]])

  # match keyword in unigrams, cast majority vote, resolve tight by order
  unigrams = unigrams.split(" | ")
  key_occ_ls = []
  key_occ_cnt = defaultdict(int)
  for gram in unigrams:
    match = match_keyword(gram)
    if match is not None:
      assert isinstance(match, str)
      print(f"keyword: {gram}, {match}")
      key_occ_ls.append((gram, match))
      key_occ_cnt[match] += 1

  if len(key_occ_ls) > 0:
    occ, cnt = sorted(key_occ_cnt.items(), key=lambda item: item[1], reverse=True)[0]
    return (cnt, occ)

  return None

# %%
import demoji
def remove_emoji(text):
  return demoji.replace(text, '')

# remove hashtag symbol
def replace_hash(text):
  return re.compile(r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))[#＃]([a-zA-Z0-9_]+)").sub(r'\1', text)

# remove hashtag sequence
def strip_hashtag_sequence(text):
  text = re.compile(r'((^|\s*)[#＃](\w+)){2,}').sub(r' ', text)
  return text

def remove_hashseq_hash_demoji(text):
  text = strip_hashtag_sequence(text)
  text = replace_hash(text)
  text = remove_emoji(text)
  return text

# remove http, @user
def remove_http_user(text):
  text = text.replace("@user", " ")
  text = text.replace("http", " ")
  return " ".join(text.split())


def strip_hashtag(text):
  # if text is not None:
  text = re.compile(r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))[#＃]([A-Za-z]+[A-Za-z0-9-_]+)").sub(r' ', text)
  return text

def replace_hash(text):
  return re.compile(r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))[#＃]([a-zA-Z0-9_]+)").sub(r'\1', text)

def strip_hashtag_sequence(text):
  text = re.compile(r'((^|\s*)[#＃](\w+)){2,}').sub(r' ', text)
  return text

def strip_url(text):
  text = re.compile(r"https?://\S+|www\.\S+").sub(r' ', text)
  return text

def replace_url(text):
  text = re.compile(r"https?://\S+|www\.\S+").sub(r' http ', text)
  return text

def strip_handle(text):
  # if text is not None:
  # https://www.nltk.org/_modules/nltk/tokenize/casual.html#TweetTokenizer
  HANDLES_RE = regex.compile(
    r"(?<![A-Za-z0-9_!@#\$%&*])@"
    r"(([A-Za-z0-9_]){15}(?!@)|([A-Za-z0-9_]){1,14}(?![A-Za-z0-9_]*@))"
  )
  text = HANDLES_RE.sub(" ", text)
  return text

def replace_handle(text):
  # https://www.nltk.org/_modules/nltk/tokenize/casual.html#TweetTokenizer
  HANDLES_RE = regex.compile(
    r"(?<![A-Za-z0-9_!@#\$%&*])@"
    r"(([A-Za-z0-9_]){15}(?!@)|([A-Za-z0-9_]){1,14}(?![A-Za-z0-9_]*@))"
  )
  text = HANDLES_RE.sub(" @user ", text)
  return text

def strip_handle_hashtag_url(text):
  if text is not None:
    text = strip_handle(text)
    text = strip_hashtag(text)
    text = strip_url(text)
  return text


def remove_digits(text):
  if isinstance(text, str):
    text = [word for word in text.split() if word.isalpha()]
    return " ".join(text)
  else:
    return None

def clean_description(text):
  if isinstance(text, str):
    text = text.lower()
    text = text.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
    text = text.replace("’", "'").replace("'s", '')
    text = strip_url(text)
    text = strip_handle(text)
    text = remove_emoji(text)
    text = contractions.fix(text) # replace contraction
    text = text.split()
    if len(text) > 0:
      return " ".join(text)
    else:
      return None
  return None

# %%
import pandas as pd
from pathlib import Path

data_dir = "/content/drive/MyDrive/SMM"
data = pd.read_csv(Path(data_dir, 'final_fear_dataset 1.csv'), sep=',',
                    index_col=0,
                    encoding="utf-8",
                    converters={
                      'user_description': clean_description,
                    },
                    dtype=str,
                    )

# lemmatization
nlp = spacy.load("en_core_web_lg")
lemmatized = []
for doc in nlp.pipe(data["user_description"].fillna('')):
  lemmatized.append(" ".join(token.lemma_ for token in doc))
data["user_description"] = lemmatized
# Out:
# <ipython-input-54-ade33cfc445e>:5: ParserWarning: Both a converter and dtype were specified for column user_description - only the converter will be used.
#   data = pd.read_csv(Path(data_dir, 'final_fear_dataset 1.csv'), sep=',',

# %%
import numpy as np
# extract unigram, bigram
data['description_12gram'] = data.user_description.map(lambda x: tokenize_ngram(x))

# extract occupation
data['occupation_tuple'] = data.description_12gram.map(lambda x: extract_occupation(x))
data['occupation'] = data.occupation_tuple.map(lambda x: x[-1] if x is not None else np.NaN)
# Out:
# Streaming output truncated to the last 5000 lines.
# unambiguous: revenue in ['<s>', 'revenue']
# ambiguous @ 1st: education in ['education', '</s>']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: community in ['community', 'online']
# unambiguous: outdoor in ['<s>', 'outdoor']
# ambiguous @ 1st: fitness in ['fitness', 'enthusiast']
# ambiguous @ 1st: education in ['education', '</s>']
# unambiguous: sound in ['I', 'sound']
# ambiguous @ 1st: sale in ['sale', '</s>']
# unambiguous: musician in ['<s>', 'musician']
# ambiguous @ 1st: human in ['human', 'nicely']
# ambiguous @ 1st: serve in ['serve', '</s>']
# ambiguous @ 1st: music in ['music', '</s>']
# ambiguous @ 1st: web in ['web', 'app']
# ambiguous @ 1st: healthcare in ['healthcare', '</s>']
# ambiguous @ 1st: study in ['study', 'compsci']
# unambiguous: manufacture in ['<s>', 'manufacture']
# ambiguous @ 1st: recovery in ['recovery', '</s>']
# ambiguous @ 1st: artist in ['artist', '</s>']
# unambiguous: program in ['ethic', 'program']
# ambiguous @ 1st: engineering in ['engineering', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: coach in ['<s>', 'coach']
# unambiguous: group in ['facebook', 'group']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: machine in ['machine', 'learning']
# ambiguous @ 1st: web in ['web', 'hosting']
# ambiguous @ 1st: space in ['space', '</s>']
# unambiguous: coffee in ['<s>', 'coffee']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: machine in ['machine', 'learning']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: musician in ['<s>', 'musician']
# unambiguous: term in ['long', 'term']
# ambiguous @ 1st: business in ['business', 'attorney']
# ambiguous @ 1st: study in ['study', 'english']
# ambiguous @ 2nd: engineering in ['software', 'engineering']
# ambiguous @ 1st: trade in ['trade', '</s>']
# ambiguous @ 1st: science in ['science', 'politic']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: computer in ['computer', 'vision']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 2nd: science in ['data', 'science']
# ambiguous @ 1st: life in ['life', 'ui']
# unambiguous: self in ['<s>', 'self']
# unambiguous: self in ['<s>', 'self']
# unambiguous: self in ['<s>', 'self']
# ambiguous @ 1st: business in ['business', '</s>']
# unambiguous: educator in ['<s>', 'educator']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: computer in ['computer', 'see']
# ambiguous @ 1st: plant in ['plant', '</s>']
# unambiguous: work in ['<s>', 'work']
# unambiguous: official in ['<s>', 'official']
# unambiguous: good in ['<s>', 'good']
# unambiguous: manufacture in ['<s>', 'manufacture']
# unambiguous: word in ['<s>', 'word']
# unambiguous: picture in ['generate', 'picture']
# ambiguous @ 1st: metal in ['metal', '</s>']
# ambiguous @ 1st: door in ['door', 'beteugele']
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: law in ['law', '</s>']
# unambiguous: new in ['<s>', 'new']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: librarian in ['<s>', 'librarian']
# ambiguous @ 1st: support in ['support', 'elon']
# ambiguous @ 1st: language in ['language', '</s>']
# ambiguous @ 1st: machine in ['machine', 'learn']
# ambiguous @ 1st: medium in ['medium', 'company']
# unambiguous: word in ['type', 'word']
# unambiguous: word in ['type', 'word']
# ambiguous @ 2nd: engineer in ['data', 'engineer']
# unambiguous: philosophy in ['<s>', 'philosophy']
# ambiguous @ 1st: science in ['science', 'denier']
# ambiguous @ 1st: law in ['law', '</s>']
# unambiguous: leader in ['<s>', 'leader']
# ambiguous @ 1st: director in ['director', '</s>']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: software in ['software', '</s>']
# ambiguous @ 1st: system in ['system', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: time in ['<s>', 'time']
# unambiguous: work in ['<s>', 'work']
# ambiguous @ 1st: first in ['first', '</s>']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# unambiguous: word in ['generate', 'word']
# ambiguous @ 1st: maker in ['maker', '</s>']
# unambiguous: researcher in ['<s>', 'researcher']
# unambiguous: work in ['tqcreative', 'work']
# unambiguous: post in ['<s>', 'post']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: member in ['member', '</s>']
# unambiguous: self in ['<s>', 'self']
# ambiguous @ 1st: machine in ['machine', 'learning']
# ambiguous @ 1st: electrical in ['electrical', 'engineering']
# ambiguous @ 1st: film in ['film', '</s>']
# ambiguous @ 1st: draw in ['draw', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# unambiguous: chief in ['<s>', 'chief']
# unambiguous: market in ['current', 'market']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: web in ['web', 'developer']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: science in ['science', '</s>']
# keyword: develop, Computer and Mathematical
# keyword: develop, Computer and Mathematical
# ambiguous @ 1st: system in ['system', 'architect']
# ambiguous @ 1st: news in ['news', 'aggregation']
# ambiguous @ 1st: life in ['life', '</s>']
# unambiguous: motion in ['human', 'motion']
# unambiguous: chief in ['<s>', 'chief']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: leader in ['business', 'leader']
# unambiguous: shop in ['<s>', 'shop']
# ambiguous @ 1st: film in ['film', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: philosophy in ['<s>', 'philosophy']
# ambiguous @ 1st: form in ['form', '</s>']
# ambiguous @ 1st: human in ['human', 'stick']
# unambiguous: researcher in ['<s>', 'researcher']
# ambiguous @ 1st: news in ['news', 'daily']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: political in ['political', 'analyst']
# ambiguous @ 1st: fast in ['fast', 'follow']
# unambiguous: project in ['<s>', 'project']
# ambiguous @ 1st: marketing in ['marketing', 'campaign']
# ambiguous @ 1st: science in ['science', 'underestimater']
# ambiguous @ 1st: pump in ['pump', 'meme']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# ambiguous @ 1st: study in ['study', 'english']
# ambiguous @ 1st: business in ['business', 'magnate']
# ambiguous @ 1st: information in ['information', 'say']
# unambiguous: project in ['<s>', 'project']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: account in ['account', '</s>']
# unambiguous: part in ['<s>', 'part']
# ambiguous @ 1st: security in ['security', 'solution']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: assistant in ['assistant', 'professor']
# ambiguous @ 1st: engineering in ['engineering', 'lead']
# unambiguous: person in ['<s>', 'person']
# ambiguous @ 1st: property in ['property', '</s>']
# unambiguous: competitor in ['<s>', 'competitor']
# ambiguous @ 1st: material in ['material', '</s>']
# unambiguous: history in ['<s>', 'history']
# ambiguous @ 1st: product in ['product', '</s>']
# ambiguous @ 1st: first in ['first', 'yoga']
# ambiguous @ 1st: metal in ['metal', '</s>']
# ambiguous @ 1st: developer in ['developer', '</s>']
# unambiguous: body in ['<s>', 'body']
# ambiguous @ 1st: care in ['care', '</s>']
# ambiguous @ 1st: product in ['product', 'designer']
# ambiguous @ 1st: political in ['political', 'priority']
# ambiguous @ 1st: software in ['software', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: architect in ['architect', '</s>']
# ambiguous @ 1st: first in ['first', 'name']
# unambiguous: fishing in ['<s>', 'fishing']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: film in ['film', '</s>']
# ambiguous @ 2nd: engineer in ['data', 'engineer']
# keyword: investor, Business and Financial Ops
# ambiguous @ 1st: real in ['real', 'estate']
# ambiguous @ 1st: home in ['home', 'run']
# ambiguous @ 1st: architect in ['architect', '</s>']
# unambiguous: image in ['seven', 'image']
# ambiguous @ 1st: engineering in ['engineering', '</s>']
# unambiguous: museum in ['<s>', 'museum']
# ambiguous @ 1st: telecommunications in ['telecommunications', '</s>']
# unambiguous: collection in ['debt', 'collection']
# unambiguous: desktop in ['<s>', 'desktop']
# unambiguous: chief in ['<s>', 'chief']
# ambiguous @ 1st: specialist in ['specialist', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: part in ['<s>', 'part']
# unambiguous: digital in ['learn', 'digital']
# ambiguous @ 1st: move in ['move', '</s>']
# unambiguous: part in ['<s>', 'part']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: word in ['generate', 'word']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# unambiguous: good in ['former', 'good']
# unambiguous: expert in ['ai', 'expert']
# unambiguous: author in ['<s>', 'author']
# unambiguous: author in ['<s>', 'author']
# keyword: ai, Computer and Mathematical
# keyword: javascript, Computer and Mathematical
# unambiguous: die in ['<s>', 'die']
# unambiguous: graphic in ['freelance', 'graphic']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: education in ['education', '</s>']
# unambiguous: history in ['modern', 'history']
# ambiguous @ 1st: account in ['account', '</s>']
# unambiguous: post in ['<s>', 'post']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 2nd: science in ['data', 'science']
# ambiguous @ 2nd: manager in ['business', 'manager']
# unambiguous: word in ['generate', 'word']
# ambiguous @ 2nd: development in ['software', 'development']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: analysis in ['insightful', 'analysis']
# unambiguous: head in ['business', 'head']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: artist in ['artist', '</s>']
# unambiguous: part in ['<s>', 'part']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: host in ['<s>', 'host']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: film in ['film', '</s>']
# ambiguous @ 1st: general in ['general', 'rave']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: news in ['news', 'aggregation']
# ambiguous @ 1st: engineer in ['engineer', 'tweet']
# ambiguous @ 1st: engineering in ['engineering', 'towards']
# ambiguous @ 1st: education in ['education', '</s>']
# unambiguous: customer in ['w', 'customer']
# ambiguous @ 1st: property in ['property', '</s>']
# unambiguous: mathematician in ['<s>', 'mathematician']
# unambiguous: new in ['<s>', 'new']
# unambiguous: self in ['future', 'self']
# ambiguous @ 1st: system in ['system', 'think']
# unambiguous: project in ['gamefi', 'project']
# ambiguous @ 1st: healthcare in ['healthcare', '</s>']
# ambiguous @ 1st: command in ['command', '</s>']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# ambiguous @ 1st: medium in ['medium', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: data in ['data', 'empower']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: work in ['<s>', 'work']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: director in ['director', '</s>']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: film in ['film', 'editor']
# unambiguous: cellular in ['<s>', 'cellular']
# unambiguous: researcher in ['<s>', 'researcher']
# unambiguous: performance in ['<s>', 'performance']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: data in ['data', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: paper in ['<s>', 'paper']
# unambiguous: electric in ['<s>', 'electric']
# ambiguous @ 1st: executive in ['executive', 'chairman']
# unambiguous: part in ['<s>', 'part']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 2nd: developer in ['software', 'developer']
# keyword: technology, Computer and Mathematical
# keyword: blockchain, Computer and Mathematical
# unambiguous: coin in ['<s>', 'coin']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# unambiguous: head in ['<s>', 'head']
# unambiguous: educator in ['<s>', 'educator']
# unambiguous: head in ['<s>', 'head']
# unambiguous: psychiatrist in ['<s>', 'psychiatrist']
# ambiguous @ 1st: study in ['study', 'medicine']
# unambiguous: head in ['<s>', 'head']
# ambiguous @ 1st: dental in ['dental', 'school']
# unambiguous: photographer in ['<s>', 'photographer']
# ambiguous @ 1st: hear in ['hear', 'I']
# ambiguous @ 1st: director in ['director', '</s>']
# ambiguous @ 1st: editor in ['editor', '</s>']
# ambiguous @ 1st: power in ['power', '</s>']
# ambiguous @ 1st: art in ['art', 'provenance']
# unambiguous: policy in ['public', 'policy']
# unambiguous: boiler in ['<s>', 'boiler']
# ambiguous @ 1st: surgeon in ['surgeon', '</s>']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: power in ['power', 'community']
# unambiguous: self in ['<s>', 'self']
# unambiguous: revenue in ['<s>', 'revenue']
# ambiguous @ 1st: human in ['human', 'advocate']
# ambiguous @ 1st: sport in ['sport', '</s>']
# ambiguous @ 1st: account in ['account', 'director']
# ambiguous @ 1st: video in ['video', '</s>']
# ambiguous @ 2nd: developer in ['software', 'developer']
# ambiguous @ 1st: draw in ['draw', '</s>']
# ambiguous @ 1st: music in ['music', '</s>']
# unambiguous: work in ['<s>', 'work']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: computer in ['computer', 'see']
# unambiguous: game in ['<s>', 'game']
# unambiguous: accountant in ['<s>', 'accountant']
# ambiguous @ 1st: data in ['data', 'breach']
# unambiguous: user in ['<s>', 'user']
# ambiguous @ 1st: first in ['first', 'step']
# unambiguous: cool in ['<s>', 'cool']
# ambiguous @ 1st: track in ['track', '</s>']
# unambiguous: register in ['checkbook', 'register']
# ambiguous @ 1st: home in ['home', '</s>']
# ambiguous @ 2nd: developer in ['software', 'developer']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: word in ['generate', 'word']
# unambiguous: curator in ['tweet', 'curator']
# ambiguous @ 1st: financial in ['financial', 'independence']
# ambiguous @ 1st: family in ['family', '</s>']
# ambiguous @ 1st: communication in ['communication', 'strategist']
# ambiguous @ 1st: human in ['human', '</s>']
# ambiguous @ 1st: study in ['study', 'english']
# unambiguous: team in ['perform', 'team']
# unambiguous: author in ['<s>', 'author']
# unambiguous: leader in ['product', 'leader']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: computer in ['computer', 'see']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: photographer in ['<s>', 'photographer']
# unambiguous: singer in ['<s>', 'singer']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: security in ['security', '</s>']
# keyword: startup, Business and Financial Ops
# ambiguous @ 1st: programmer in ['programmer', '</s>']
# ambiguous @ 1st: developer in ['developer', '</s>']
# unambiguous: project in ['side', 'project']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: information in ['information', 'management']
# ambiguous @ 1st: support in ['support', '</s>']
# unambiguous: turn in ['writer', 'turn']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 2nd: operation in ['business', 'operation']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: chief in ['<s>', 'chief']
# ambiguous @ 1st: web in ['web', 'content']
# ambiguous @ 2nd: scientist in ['data', 'scientist']
# unambiguous: person in ['bored', 'person']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: musical in ['pizazz', 'musical']
# ambiguous @ 1st: personal in ['personal', 'ai']
# unambiguous: day in ['<s>', 'day']
# ambiguous @ 1st: medium in ['medium', 'company']
# ambiguous @ 1st: art in ['art', 'enthusiast']
# unambiguous: promoter in ['<s>', 'promoter']
# ambiguous @ 2nd: development in ['software', 'development']
# ambiguous @ 1st: director in ['director', '</s>']
# ambiguous @ 1st: security in ['security', '</s>']
# ambiguous @ 1st: planner in ['planner', '</s>']
# ambiguous @ 1st: crew in ['crew', '</s>']
# unambiguous: quality in ['offer', 'quality']
# ambiguous @ 1st: research in ['research', 'lab']
# unambiguous: author in ['<s>', 'author']
# unambiguous: hard in ['<s>', 'hard']
# unambiguous: boring in ['overall', 'boring']
# ambiguous @ 1st: career in ['career', '</s>']
# ambiguous @ 1st: information in ['information', 'management']
# ambiguous @ 1st: teacher in ['teacher', 'make']
# unambiguous: stock in ['<s>', 'stock']
# unambiguous: digital in ['<s>', 'digital']
# keyword: ai, Computer and Mathematical
# unambiguous: person in ['savy', 'person']
# unambiguous: lawyer in ['<s>', 'lawyer']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: researcher in ['phd', 'researcher']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: change in ['positive', 'change']
# unambiguous: quality in ['<s>', 'quality']
# ambiguous @ 1st: medium in ['medium', 'company']
# ambiguous @ 1st: computer in ['computer', '</s>']
# unambiguous: day in ['business', 'day']
# ambiguous @ 1st: first in ['first', '</s>']
# ambiguous @ 1st: fast in ['fast', '</s>']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# unambiguous: non in ['<s>', 'non']
# ambiguous @ 1st: plastic in ['plastic', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: stone in ['stone', 'mountain']
# ambiguous @ 1st: product in ['product', 'designer']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# ambiguous @ 1st: artist in ['artist', 'inside']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: system in ['system', '</s>']
# ambiguous @ 1st: engineering in ['engineering', 'towards']
# ambiguous @ 1st: data in ['data', 'jedi']
# ambiguous @ 1st: engineering in ['engineering', 'towards']
# keyword: ai, Computer and Mathematical
# unambiguous: work in ['<s>', 'work']
# unambiguous: activity in ['twitter', 'activity']
# ambiguous @ 2nd: officer in ['medical', 'officer']
# ambiguous @ 1st: security in ['security', '</s>']
# unambiguous: team in ['devops', 'team']
# ambiguous @ 1st: development in ['development', 'manager']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# ambiguous @ 1st: tool in ['tool', '</s>']
# unambiguous: person in ['real', 'person']
# ambiguous @ 1st: financial in ['financial', 'advisor']
# unambiguous: expert in ['web', 'expert']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: expert in ['digitalmarketing', 'expert']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# unambiguous: basic in ['<s>', 'basic']
# unambiguous: game in ['mind', 'game']
# unambiguous: team in ['<s>', 'team']
# unambiguous: market in ['<s>', 'market']
# ambiguous @ 1st: executive in ['executive', '</s>']
# unambiguous: coffee in ['<s>', 'coffee']
# ambiguous @ 1st: news in ['news', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: news in ['news', 'company']
# ambiguous @ 1st: account in ['account', '</s>']
# ambiguous @ 1st: first in ['first', 'daily']
# ambiguous @ 1st: life in ['life', 'long']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: good in ['<s>', 'good']
# unambiguous: register in ['checkbook', 'register']
# keyword: ai, Computer and Mathematical
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: account in ['account', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: network in ['network', '</s>']
# ambiguous @ 1st: specialist in ['specialist', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: engineer in ['engineer', 'study']
# unambiguous: change in ['might', 'change']
# ambiguous @ 1st: teacher in ['teacher', '</s>']
# unambiguous: host in ['space', 'host']
# unambiguous: justice in ['social', 'justice']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: personal in ['personal', '</s>']
# unambiguous: coach in ['accessibility', 'coach']
# ambiguous @ 1st: member in ['member', 'streaming']
# unambiguous: project in ['seo', 'project']
# ambiguous @ 2nd: developer in ['software', 'developer']
# ambiguous @ 1st: real in ['real', '</s>']
# unambiguous: good in ['<s>', 'good']
# unambiguous: tree in ['<s>', 'tree']
# ambiguous @ 1st: medium in ['medium', '</s>']
# ambiguous @ 1st: community in ['community', 'manager']
# unambiguous: turn in ['founder', 'turn']
# ambiguous @ 1st: private in ['private', 'investor']
# unambiguous: fill in ['<s>', 'fill']
# ambiguous @ 1st: support in ['support', 'specialist']
# ambiguous @ 1st: software in ['software', 'type']
# ambiguous @ 1st: web in ['web', 'developer']
# ambiguous @ 1st: private in ['private', 'lender']
# unambiguous: game in ['<s>', 'game']
# ambiguous @ 1st: transportation in ['transportation', 'engineering']
# ambiguous @ 1st: move in ['move', '</s>']
# ambiguous @ 1st: development in ['development', '</s>']
# unambiguous: musician in ['synthwave', 'musician']
# ambiguous @ 1st: development in ['development', '</s>']
# unambiguous: good in ['really', 'good']
# ambiguous @ 1st: security in ['security', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: business in ['business', 'owner']
# ambiguous @ 1st: private in ['private', 'lender']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: real in ['real', 'mark']
# ambiguous @ 1st: first in ['first', '</s>']
# unambiguous: stock in ['<s>', 'stock']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: security in ['security', '</s>']
# ambiguous @ 1st: manager in ['manager', '</s>']
# ambiguous @ 1st: food in ['food', 'lover']
# ambiguous @ 1st: web in ['web', 'dev']
# ambiguous @ 1st: specialist in ['specialist', '</s>']
# unambiguous: religion in ['<s>', 'religion']
# ambiguous @ 1st: life in ['life', 'great']
# ambiguous @ 1st: web in ['web', 'developer']
# ambiguous @ 1st: web in ['web', 'developer']
# ambiguous @ 1st: web in ['web', 'developer']
# ambiguous @ 1st: support in ['support', 'eo']
# ambiguous @ 1st: business in ['business', 'cyber']
# ambiguous @ 1st: collector in ['collector', '</s>']
# ambiguous @ 2nd: science in ['computer', 'science']
# ambiguous @ 1st: information in ['information', 'online']
# unambiguous: religion in ['<s>', 'religion']
# unambiguous: day in ['<s>', 'day']
# ambiguous @ 1st: communication in ['communication', '</s>']
# ambiguous @ 1st: personal in ['personal', 'ai']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: product in ['product', 'designer']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: scientist in ['scientist', 'supervillain']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: tool in ['tool', 'hunter']
# unambiguous: game in ['<s>', 'game']
# unambiguous: mathematician in ['professional', 'mathematician']
# ambiguous @ 1st: earth in ['earth', 'I']
# unambiguous: musician in ['synthwave', 'musician']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: time in ['<s>', 'time']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: english in ['english', '</s>']
# ambiguous @ 1st: study in ['study', 'english']
# keyword: leadership, Management
# unambiguous: street in ['<s>', 'street']
# ambiguous @ 1st: community in ['community', '</s>']
# unambiguous: analysis in ['star', 'analysis']
# unambiguous: host in ['educate', 'host']
# ambiguous @ 1st: security in ['security', 'enthusiast']
# ambiguous @ 1st: service in ['service', '</s>']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: research in ['research', 'via']
# unambiguous: desktop in ['<s>', 'desktop']
# ambiguous @ 1st: science in ['science', '</s>']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: product in ['product', 'director']
# ambiguous @ 1st: service in ['service', 'create']
# unambiguous: quality in ['support', 'quality']
# ambiguous @ 1st: personal in ['personal', 'account']
# unambiguous: game in ['<s>', 'game']
# ambiguous @ 2nd: assistant in ['research', 'assistant']
# ambiguous @ 1st: product in ['product', '</s>']
# ambiguous @ 1st: business in ['business', 'newspaper']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: machine in ['machine', 'learn']
# unambiguous: educator in ['business', 'educator']
# unambiguous: author in ['<s>', 'author']
# unambiguous: new in ['learn', 'new']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: business in ['business', '</s>']
# unambiguous: small in ['<s>', 'small']
# ambiguous @ 2nd: scientist in ['medical', 'scientist']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# unambiguous: history in ['<s>', 'history']
# ambiguous @ 1st: tool in ['tool', 'hunter']
# ambiguous @ 1st: air in ['air', 'wave']
# unambiguous: watch in ['<s>', 'watch']
# ambiguous @ 1st: language in ['language', '</s>']
# ambiguous @ 1st: technologist in ['technologist', '</s>']
# ambiguous @ 1st: engineering in ['engineering', 'towards']
# ambiguous @ 1st: human in ['human', '</s>']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: technologist in ['technologist', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: support in ['support', 'racism']
# ambiguous @ 1st: care in ['care', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: first in ['first', 'generation']
# unambiguous: chemistry in ['<s>', 'chemistry']
# unambiguous: market in ['<s>', 'market']
# keyword: startup, Business and Financial Ops
# ambiguous @ 1st: sale in ['sale', '</s>']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 1st: food in ['food', 'editor']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# unambiguous: day in ['product', 'day']
# ambiguous @ 1st: personal in ['personal', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: analyst in ['analyst', '</s>']
# ambiguous @ 1st: power in ['power', 'research']
# ambiguous @ 1st: earth in ['earth', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: cut in ['<s>', 'cut']
# unambiguous: stock in ['<s>', 'stock']
# unambiguous: wall in ['<s>', 'wall']
# ambiguous @ 1st: control in ['control', '</s>']
# ambiguous @ 1st: research in ['research', 'fellow']
# unambiguous: compliance in ['gdpr', 'compliance']
# unambiguous: time in ['long', 'time']
# ambiguous @ 1st: social in ['social', 'network']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: study in ['study', 'compsci']
# unambiguous: digital in ['ipfconline', 'digital']
# ambiguous @ 1st: health in ['health', '</s>']
# unambiguous: builder in ['web3', 'builder']
# ambiguous @ 1st: medical in ['medical', 'curriculum']
# ambiguous @ 1st: property in ['property', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: educator in ['<s>', 'educator']
# unambiguous: mathematician in ['professional', 'mathematician']
# ambiguous @ 1st: web in ['web', 'app']
# ambiguous @ 1st: mobile in ['mobile', 'app']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: move in ['move', 'forward']
# ambiguous @ 1st: move in ['move', 'forward']
# ambiguous @ 1st: social in ['social', 'medium']
# unambiguous: stock in ['<s>', 'stock']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: fitness in ['fitness', 'enthusiast']
# ambiguous @ 1st: fitness in ['fitness', 'enthusiast']
# ambiguous @ 1st: life in ['life', 'give']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: first in ['first', '</s>']
# ambiguous @ 1st: first in ['first', '</s>']
# ambiguous @ 1st: network in ['network', '</s>']
# unambiguous: leader in ['marketing', 'leader']
# unambiguous: market in ['<s>', 'market']
# ambiguous @ 2nd: information in ['management', 'information']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: building in ['building', '</s>']
# ambiguous @ 1st: building in ['building', '</s>']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# ambiguous @ 2nd: developer in ['software', 'developer']
# ambiguous @ 1st: commercial in ['commercial', 'litigation']
# unambiguous: set in ['<s>', 'set']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: civil in ['civil', '</s>']
# unambiguous: dancer in ['sanatani', 'dancer']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: order in ['order', '</s>']
# ambiguous @ 1st: order in ['order', '</s>']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# ambiguous @ 1st: science in ['science', '</s>']
# ambiguous @ 1st: financial in ['financial', 'advice']
# ambiguous @ 1st: music in ['music', '</s>']
# ambiguous @ 1st: personal in ['personal', '</s>']
# ambiguous @ 1st: computer in ['computer', '</s>']
# ambiguous @ 1st: music in ['music', 'labs']
# ambiguous @ 1st: human in ['human', 'meet']
# ambiguous @ 1st: human in ['human', 'creativity']
# unambiguous: desktop in ['<s>', 'desktop']
# ambiguous @ 1st: engineering in ['engineering', 'towards']
# ambiguous @ 2nd: engineering in ['computer', 'engineering']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 2nd: science in ['data', 'science']
# ambiguous @ 1st: school in ['school', 'jew']
# unambiguous: market in ['<s>', 'market']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: mobile in ['mobile', 'apps\u200d']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: human in ['human', '</s>']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: account in ['account', '</s>']
# unambiguous: rock in ['capitalism', 'rock']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: financial in ['financial', 'decision']
# ambiguous @ 1st: legal in ['legal', '</s>']
# unambiguous: builder in ['web3', 'builder']
# ambiguous @ 1st: first in ['first', 'daily']
# unambiguous: time in ['<s>', 'time']
# unambiguous: author in ['<s>', 'author']
# keyword: ai, Computer and Mathematical
# unambiguous: yard in ['friendly', 'yard']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: social in ['social', 'medium']
# ambiguous @ 1st: personal in ['personal', '</s>']
# unambiguous: analysis in ['american', 'analysis']
# keyword: investor, Business and Financial Ops
# unambiguous: multiple in ['<s>', 'multiple']
# unambiguous: expert in ['ex', 'expert']
# unambiguous: expert in ['ex', 'expert']
# unambiguous: work in ['currently', 'work']
# unambiguous: chief in ['<s>', 'chief']
# ambiguous @ 1st: study in ['study', '</s>']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 2nd: developer in ['software', 'developer']
# unambiguous: coach in ['I', 'coach']
# unambiguous: host in ['<s>', 'host']
# ambiguous @ 1st: school in ['school', 'raver']
# unambiguous: speech in ['<s>', 'speech']
# unambiguous: die in ['<s>', 'die']
# unambiguous: person in ['ordinary', 'person']
# unambiguous: market in ['<s>', 'market']
# ambiguous @ 1st: personal in ['personal', 'ai']
# ambiguous @ 1st: animal in ['animal', '</s>']
# unambiguous: project in ['<s>', 'project']
# ambiguous @ 1st: engineering in ['engineering', 'towards']
# ambiguous @ 1st: life in ['life', '</s>']
# keyword: technology, Computer and Mathematical
# ambiguous @ 1st: management in ['management', '</s>']
# ambiguous @ 1st: mental in ['mental', 'exercise']
# ambiguous @ 1st: private in ['private', 'capital']
# ambiguous @ 1st: personal in ['personal', 'ai']
# unambiguous: cut in ['<s>', 'cut']
# unambiguous: natural in ['<s>', 'natural']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 2nd: scientist in ['health', 'scientist']
# unambiguous: captain in ['<s>', 'captain']
# ambiguous @ 1st: first in ['first', 'daily']
# ambiguous @ 1st: social in ['social', 'medium']
# ambiguous @ 1st: human in ['human', '</s>']
# ambiguous @ 1st: social in ['social', '</s>']
# unambiguous: digital in ['annual', 'digital']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: account in ['account', '</s>']
# unambiguous: outdoor in ['<s>', 'outdoor']
# unambiguous: government in ['<s>', 'government']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: power in ['power', '</s>']
# unambiguous: baker in ['professional', 'baker']
# ambiguous @ 1st: special in ['special', '</s>']
# unambiguous: risk in ['hedgeye', 'risk']
# unambiguous: quality in ['air', 'quality']
# ambiguous @ 1st: home in ['home', 'service']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: person in ['music', 'person']
# unambiguous: cool in ['<s>', 'cool']
# ambiguous @ 1st: human in ['human', '</s>']
# unambiguous: watch in ['I', 'watch']
# unambiguous: work in ['<s>', 'work']
# unambiguous: educator in ['<s>', 'educator']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 2nd: director in ['art', 'director']
# ambiguous @ 1st: personal in ['personal', 'ai']
# unambiguous: educator in ['<s>', 'educator']
# unambiguous: tutor in ['test', 'tutor']
# unambiguous: commodity in ['<s>', 'commodity']
# unambiguous: cut in ['<s>', 'cut']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: study in ['study', 'compsci']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: building in ['building', '</s>']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# unambiguous: paper in ['<s>', 'paper']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 2nd: engineering in ['software', 'engineering']
# ambiguous @ 1st: life in ['life', 'great']
# ambiguous @ 1st: life in ['life', 'great']
# keyword: startup, Business and Financial Ops
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: education in ['education', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: desktop in ['<s>', 'desktop']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 2nd: science in ['data', 'science']
# unambiguous: journalist in ['incoming', 'journalist']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# unambiguous: speech in ['<s>', 'speech']
# keyword: investor, Business and Financial Ops
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: research in ['research', '</s>']
# ambiguous @ 2nd: developer in ['software', 'developer']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: communication in ['communication', '</s>']
# ambiguous @ 1st: mobile in ['mobile', 'dev']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: music in ['music', '</s>']
# unambiguous: author in ['horror', 'author']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 1st: developer in ['developer', 'advocate']
# keyword: javascript, Computer and Mathematical
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: life in ['life', '</s>']
# unambiguous: host in ['<s>', 'host']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# unambiguous: project in ['photography', 'project']
# unambiguous: turn in ['<s>', 'turn']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: treat in ['treat', 'everyday']
# ambiguous @ 1st: tank in ['tank', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: engineering in ['engineering', '</s>']
# unambiguous: exhibit in ['pixelism', 'exhibit']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: developer in ['developer', 'advocate']
# unambiguous: compliance in ['gdpr', 'compliance']
# ambiguous @ 1st: technologist in ['technologist', '</s>']
# ambiguous @ 1st: audio in ['audio', 'engineer']
# ambiguous @ 1st: writer in ['writer', 'copywriter']
# unambiguous: event in ['extreme', 'event']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: travel in ['travel', 'tech']
# unambiguous: lawyer in ['<s>', 'lawyer']
# ambiguous @ 1st: human in ['human', '</s>']
# ambiguous @ 1st: space in ['space', '</s>']
# unambiguous: journalist in ['<s>', 'journalist']
# unambiguous: book in ['old', 'book']
# ambiguous @ 1st: cutting in ['cutting', '</s>']
# ambiguous @ 1st: science in ['science', '</s>']
# ambiguous @ 1st: study in ['study', 'english']
# unambiguous: time in ['<s>', 'time']
# unambiguous: effect in ['side', 'effect']
# unambiguous: educator in ['<s>', 'educator']
# ambiguous @ 1st: control in ['control', '</s>']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: writer in ['writer', 'tweet']
# ambiguous @ 1st: serve in ['serve', '</s>']
# unambiguous: accountant in ['charter', 'accountant']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: first in ['first', 'south']
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: information in ['information', '</s>']
# unambiguous: chief in ['<s>', 'chief']
# ambiguous @ 1st: environmental in ['environmental', 'issue']
# unambiguous: cut in ['<s>', 'cut']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# unambiguous: new in ['<s>', 'new']
# unambiguous: cut in ['<s>', 'cut']
# unambiguous: economic in ['<s>', 'economic']
# unambiguous: purchase in ['<s>', 'purchase']
# ambiguous @ 1st: human in ['human', '</s>']
# ambiguous @ 1st: manager in ['manager', '</s>']
# unambiguous: policy in ['<s>', 'policy']
# ambiguous @ 1st: track in ['track', 'winner']
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: community in ['community', '</s>']
# unambiguous: expert in ['discord', 'expert']
# ambiguous @ 1st: hand in ['hand', '</s>']
# ambiguous @ 1st: teaching in ['teaching', '</s>']
# ambiguous @ 1st: editor in ['editor', '</s>']
# ambiguous @ 1st: product in ['product', '</s>']
# ambiguous @ 1st: web in ['web', 'developer']
# unambiguous: game in ['start', 'game']
# ambiguous @ 1st: water in ['water', '</s>']
# ambiguous @ 1st: public in ['public', 'philosopher']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 2nd: developer in ['software', 'developer']
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: bus in ['bus', 'pass']
# ambiguous @ 1st: software in ['software', '</s>']
# ambiguous @ 1st: language in ['language', 'allow']
# keyword: dev, Computer and Mathematical
# unambiguous: self in ['<s>', 'self']
# ambiguous @ 1st: tool in ['tool', '</s>']
# unambiguous: process in ['urbanismo', 'process']
# unambiguous: actor in ['<s>', 'actor']
# unambiguous: builder in ['community', 'builder']
# unambiguous: customer in ['<s>', 'customer']
# ambiguous @ 1st: engineering in ['engineering', '</s>']
# unambiguous: coffee in ['drink', 'coffee']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: history in ['<s>', 'history']
# ambiguous @ 1st: writer in ['writer', '</s>']
# keyword: ai, Computer and Mathematical
# keyword: consultant, Business and Financial Ops
# keyword: technology, Computer and Mathematical
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: power in ['power', '</s>']
# ambiguous @ 1st: education in ['education', '</s>']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# unambiguous: justice in ['social', 'justice']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: handle in ['handle', '</s>']
# ambiguous @ 1st: news in ['news', 'portal']
# ambiguous @ 1st: architect in ['architect', '</s>']
# ambiguous @ 2nd: analyst in ['data', 'analyst']
# ambiguous @ 1st: real in ['real', '</s>']
# unambiguous: non in ['<s>', 'non']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: psychology in ['phd', 'psychology']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: medium in ['medium', 'production']
# ambiguous @ 1st: power in ['power', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# unambiguous: musical in ['pizazz', 'musical']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# ambiguous @ 1st: personal in ['personal', 'ai']
# ambiguous @ 1st: product in ['product', '</s>']
# unambiguous: game in ['<s>', 'game']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: history in ['<s>', 'history']
# unambiguous: book in ['<s>', 'book']
# ambiguous @ 1st: specialist in ['specialist', '</s>']
# unambiguous: desktop in ['<s>', 'desktop']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: food in ['food', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: insurance in ['insurance', 'adjuster']
# unambiguous: self in ['<s>', 'self']
# unambiguous: economic in ['<s>', 'economic']
# unambiguous: cool in ['<s>', 'cool']
# unambiguous: picture in ['nitefall', 'picture']
# unambiguous: educator in ['<s>', 'educator']
# unambiguous: host in ['podcast', 'host']
# ambiguous @ 1st: tax in ['tax', '</s>']
# unambiguous: project in ['sr', 'project']
# ambiguous @ 1st: web in ['web', 'dev丨sarcastic']
# ambiguous @ 1st: power in ['power', '</s>']
# unambiguous: producer in ['<s>', 'producer']
# ambiguous @ 1st: artist in ['artist', 'virtual']
# unambiguous: project in ['sr', 'project']
# ambiguous @ 1st: gas in ['gas', 'raman']
# unambiguous: post in ['<s>', 'post']
# ambiguous @ 1st: construction in ['construction', 'supply']
# ambiguous @ 1st: service in ['service', '</s>']
# ambiguous @ 1st: product in ['product', '</s>']
# unambiguous: motion in ['human', 'motion']
# unambiguous: motion in ['human', 'motion']
# unambiguous: motion in ['human', 'motion']
# ambiguous @ 1st: artist in ['artist', '</s>']
# unambiguous: motion in ['human', 'motion']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# unambiguous: die in ['<s>', 'die']
# unambiguous: musical in ['pizazz', 'musical']
# ambiguous @ 1st: social in ['social', '</s>']
# ambiguous @ 1st: include in ['include', '</s>']
# ambiguous @ 2nd: analyst in ['data', 'analyst']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: account in ['account', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: web in ['web', 'developer']
# unambiguous: desktop in ['<s>', 'desktop']
# ambiguous @ 1st: product in ['product', 'company']
# ambiguous @ 1st: guide in ['guide', 'purpose']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# ambiguous @ 1st: medium in ['medium', '</s>']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: game in ['video', 'game']
# ambiguous @ 1st: product in ['product', 'management']
# ambiguous @ 1st: writer in ['writer', '</s>']
# unambiguous: researcher in ['digitalmarketing', 'researcher']
# ambiguous @ 1st: film in ['film', 'critic']
# keyword: coding, Computer and Mathematical
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: account in ['account', '</s>']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# unambiguous: history in ['<s>', 'history']
# ambiguous @ 1st: public in ['public', 'bio']
# ambiguous @ 1st: security in ['security', '</s>']
# ambiguous @ 1st: software in ['software', 'company']
# unambiguous: day in ['<s>', 'day']
# unambiguous: visual in ['chatgpt', 'visual']
# unambiguous: book in ['comic', 'book']
# unambiguous: researcher in ['<s>', 'researcher']
# unambiguous: cut in ['<s>', 'cut']
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: life in ['life', '</s>']
# ambiguous @ 1st: home in ['home', '</s>']
# ambiguous @ 1st: sport in ['sport', 'analyst']
# ambiguous @ 1st: tank in ['tank', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: architect in ['architect', '</s>']
# ambiguous @ 1st: engineering in ['engineering', '</s>']
# unambiguous: turn in ['gpt4', 'turn']
# ambiguous @ 1st: public in ['public', 'update']
# ambiguous @ 1st: director in ['director', '</s>']
# ambiguous @ 1st: video in ['video', '</s>']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# unambiguous: head in ['<s>', 'head']
# ambiguous @ 1st: research in ['research', '</s>']
# unambiguous: work in ['gamedev', 'work']
# unambiguous: new in ['<s>', 'new']
# unambiguous: non in ['<s>', 'non']
# unambiguous: time in ['<s>', 'time']
# ambiguous @ 1st: music in ['music', '</s>']
# unambiguous: good in ['<s>', 'good']
# unambiguous: cardiologist in ['preventive', 'cardiologist']
# unambiguous: small in ['<s>', 'small']
# unambiguous: time in ['take', 'time']
# unambiguous: chief in ['<s>', 'chief']
# ambiguous @ 2nd: developer in ['software', 'developer']
# unambiguous: structure in ['entrepreneur', 'structure']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: video in ['video', 'production']
# ambiguous @ 1st: private in ['private', 'datum']
# ambiguous @ 1st: music in ['music', '</s>']
# ambiguous @ 1st: social in ['social', 'media']
# ambiguous @ 1st: system in ['system', 'scientist']
# ambiguous @ 1st: account in ['account', 'dare']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: actor in ['<s>', 'actor']
# unambiguous: official in ['sirpeter', 'official']
# ambiguous @ 2nd: officer in ['research', 'officer']
# ambiguous @ 1st: sport in ['sport', 'analyst']
# unambiguous: journalist in ['freelance', 'journalist']
# ambiguous @ 1st: trainer in ['trainer', 'youtube']
# unambiguous: filter in ['tweet', 'filter']
# keyword: ai, Computer and Mathematical
# keyword: investor, Business and Financial Ops
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: analyst in ['analyst', '</s>']
# ambiguous @ 1st: relation in ['relation', '</s>']
# unambiguous: work in ['<s>', 'work']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: space in ['space', '</s>']
# ambiguous @ 1st: social in ['social', 'media']
# ambiguous @ 1st: service in ['service', 'designer']
# unambiguous: paper in ['<s>', 'paper']
# unambiguous: effect in ['butterfly', 'effect']
# unambiguous: watch in ['always', 'watch']
# unambiguous: time in ['<s>', 'time']
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: service in ['service', '</s>']
# keyword: entrepreneur, Computer and Mathematical
# unambiguous: reader in ['ardent', 'reader']
# ambiguous @ 1st: reporter in ['reporter', '</s>']
# ambiguous @ 1st: reporter in ['reporter', '</s>']
# ambiguous @ 1st: study in ['study', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 2nd: specialist in ['marketing', 'specialist']
# ambiguous @ 2nd: specialist in ['marketing', 'specialist']
# unambiguous: game in ['video', 'game']
# ambiguous @ 1st: web in ['web', 'dev']
# unambiguous: watch in ['always', 'watch']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: support in ['support', '</s>']
# ambiguous @ 1st: political in ['political', 'news']
# ambiguous @ 1st: first in ['first', '</s>']
# ambiguous @ 1st: loan in ['loan', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# unambiguous: producer in ['music', 'producer']
# ambiguous @ 1st: account in ['account', '</s>']
# ambiguous @ 1st: assistant in ['assistant', 'scoutmaster']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# ambiguous @ 1st: business in ['business', 'people']
# ambiguous @ 1st: business in ['business', 'people']
# ambiguous @ 2nd: science in ['data', 'science']
# ambiguous @ 1st: web in ['web', '</s>']
# ambiguous @ 1st: artist in ['artist', '</s>']
# unambiguous: leader in ['thought', 'leader']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# ambiguous @ 1st: network in ['network', '</s>']
# ambiguous @ 1st: worker in ['worker', 'professional']
# ambiguous @ 1st: training in ['training', 'lover']
# unambiguous: leader in ['think', 'leader']
# unambiguous: cut in ['<s>', 'cut']
# ambiguous @ 1st: human in ['human', 'progress']
# unambiguous: policy in ['public', 'policy']
# ambiguous @ 1st: science in ['science', '</s>']
# unambiguous: official in ['<s>', 'official']
# unambiguous: leader in ['senior', 'leader']
# ...
# unambiguous: official in ['<s>', 'official']
# unambiguous: work in ['<s>', 'work']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 1st: teacher in ['teacher', 'deliver']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: support in ['support', 'people']
# ambiguous @ 1st: security in ['security', 'make']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: education in ['education', 'provider']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: head in ['<s>', 'head']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: writer in ['writer', '</s>']
# ambiguous @ 1st: mobile in ['mobile', '</s>']
# ambiguous @ 1st: mobile in ['mobile', 'security']
# ambiguous @ 1st: business in ['business', '</s>']
# keyword: ai, Computer and Mathematical
# keyword: cybersecurity, Computer and Mathematical
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: web in ['web', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: still in ['<s>', 'still']
# unambiguous: person in ['simple', 'person']
# unambiguous: person in ['simple', 'person']
# unambiguous: person in ['simple', 'person']
# unambiguous: person in ['simple', 'person']
# unambiguous: person in ['simple', 'person']
# unambiguous: still in ['<s>', 'still']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# keyword: cybersecurity, Computer and Mathematical
# unambiguous: competitor in ['<s>', 'competitor']
# unambiguous: still in ['<s>', 'still']
# ambiguous @ 1st: art in ['art', '</s>']
# ambiguous @ 2nd: engineer in ['software', 'engineer']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: software in ['software', '</s>']
# ambiguous @ 1st: security in ['security', 'bene']
# ambiguous @ 1st: account in ['account', '</s>']
# unambiguous: game in ['<s>', 'game']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: healthcare in ['healthcare', 'executive']
# unambiguous: educator in ['<s>', 'educator']
# ambiguous @ 1st: computer in ['computer', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: network in ['network', 'professional']
# ambiguous @ 1st: manager in ['manager', '</s>']
# unambiguous: self in ['<s>', 'self']
# unambiguous: policy in ['health', 'policy']
# unambiguous: group in ['prospitalia', 'group']
# ambiguous @ 1st: tool in ['tool', '</s>']
# unambiguous: automate in ['service', 'automate']
# ambiguous @ 1st: security in ['security', 'director']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: law in ['law', 'student']
# ambiguous @ 1st: tank in ['tank', '</s>']
# ambiguous @ 1st: power in ['power', '</s>']
# ambiguous @ 1st: machine in ['machine', '</s>']
# unambiguous: work in ['recruiter', 'work']
# unambiguous: team in ['soc', 'team']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# ambiguous @ 1st: manager in ['manager', '</s>']
# ambiguous @ 2nd: security in ['data', 'security']
# ambiguous @ 1st: tank in ['tank', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: information in ['information', 'security']
# ambiguous @ 1st: medium in ['medium', 'industry']
# ambiguous @ 1st: space in ['space', '</s>']
# ambiguous @ 1st: engineer in ['engineer', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: library in ['library', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: director in ['director', '</s>']
# ambiguous @ 1st: library in ['library', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: first in ['first', 'independent']
# ambiguous @ 1st: collector in ['collector', '</s>']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 1st: personal in ['personal', 'via']
# ambiguous @ 1st: safety in ['safety', '</s>']
# unambiguous: still in ['<s>', 'still']
# ambiguous @ 1st: safety in ['safety', '</s>']
# ambiguous @ 1st: news in ['news', 'simplify']
# ambiguous @ 1st: community in ['community', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# keyword: blockchain, Computer and Mathematical
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: machine in ['machine', '</s>']
# ambiguous @ 1st: information in ['information', 'security']
# unambiguous: craft in ['<s>', 'craft']
# ambiguous @ 1st: collector in ['collector', '</s>']
# ambiguous @ 1st: news in ['news', 'outlet']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 1st: artist in ['artist', 'creator']
# ambiguous @ 1st: software in ['software', '</s>']
# unambiguous: graphic in ['<s>', 'graphic']
# unambiguous: graphic in ['<s>', 'graphic']
# ambiguous @ 1st: power in ['power', '</s>']
# ambiguous @ 1st: physician in ['physician', '</s>']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 1st: news in ['news', 'aggregation']
# ambiguous @ 1st: director in ['director', '</s>']
# unambiguous: economic in ['<s>', 'economic']
# ambiguous @ 1st: director in ['director', '</s>']
# unambiguous: device in ['<s>', 'device']
# ambiguous @ 1st: fast in ['fast', '</s>']
# ambiguous @ 1st: developer in ['developer', '</s>']
# unambiguous: author in ['<s>', 'author']
# unambiguous: chemistry in ['crypto', 'chemistry']
# unambiguous: author in ['<s>', 'author']
# unambiguous: author in ['<s>', 'author']
# ambiguous @ 1st: first in ['first', '</s>']
# unambiguous: risk in ['privacy', 'risk']
# unambiguous: lawyer in ['tech', 'lawyer']
# ambiguous @ 1st: scientist in ['scientist', '</s>']
# ambiguous @ 1st: security in ['security', '</s>']
# ambiguous @ 1st: real in ['real', '</s>']
# keyword: cybersecurity, Computer and Mathematical
# ambiguous @ 1st: security in ['security', 'service']
# ambiguous @ 1st: communication in ['communication', 'specialist']
# unambiguous: official in ['<s>', 'official']
# unambiguous: expert in ['access', 'expert']
# ambiguous @ 1st: artist in ['artist', '</s>']
# ambiguous @ 1st: tank in ['tank', '</s>']
# unambiguous: program in ['ethic', 'program']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: service in ['service', '</s>']
# unambiguous: compliance in ['gdpr', 'compliance']
# unambiguous: part in ['<s>', 'part']
# keyword: technology, Computer and Mathematical
# ambiguous @ 1st: education in ['education', '</s>']
# ambiguous @ 1st: mobile in ['mobile', 'security']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: legal in ['legal', 'help']
# ambiguous @ 1st: business in ['business', 'daily']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: development in ['development', '</s>']
# ambiguous @ 1st: analyst in ['analyst', '</s>']
# unambiguous: game in ['exciting', 'game']
# unambiguous: runner in ['<s>', 'runner']
# ambiguous @ 1st: service in ['service', '</s>']
# unambiguous: time in ['dividend', 'time']
# ambiguous @ 1st: member in ['member', 'envato']
# unambiguous: team in ['<s>', 'team']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: security in ['security', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: official in ['<s>', 'official']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: change in ['<s>', 'change']
# keyword: leadership, Management
# keyword: cybersecurity, Computer and Mathematical
# ambiguous @ 1st: enforcement in ['enforcement', 'protocol']
# ambiguous @ 1st: security in ['security', 'accessible']
# keyword: ml, Computer and Mathematical
# ambiguous @ 1st: public in ['public', 'affairs']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: security in ['security', '</s>']
# ambiguous @ 2nd: development in ['software', 'development']
# unambiguous: work in ['<s>', 'work']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 2nd: development in ['software', 'development']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: designer in ['designer', '</s>']
# keyword: technology, Computer and Mathematical
# ambiguous @ 1st: business in ['business', 'owner']
# ambiguous @ 1st: travel in ['travel', '</s>']
# ambiguous @ 1st: developer in ['developer', '</s>']
# unambiguous: expert in ['cybersecurity', 'expert']
# ambiguous @ 1st: software in ['software', '</s>']
# ambiguous @ 1st: communication in ['communication', 'agency']
# ambiguous @ 2nd: science in ['data', 'science']
# ambiguous @ 1st: fast in ['fast', '</s>']
# ambiguous @ 1st: food in ['food', '</s>']
# ambiguous @ 1st: tool in ['tool', 'available']
# ambiguous @ 1st: travel in ['travel', '</s>']
# unambiguous: author in ['<s>', 'author']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: building in ['building', 'tool']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: security in ['security', '</s>']
# unambiguous: small in ['<s>', 'small']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: production in ['production', 'company']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: security in ['security', 'worker']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: collector in ['collector', '</s>']
# ambiguous @ 1st: assistant in ['assistant', '</s>']
# ambiguous @ 1st: architect in ['architect', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: accountant in ['big4', 'accountant']
# ambiguous @ 1st: study in ['study', 'center']
# ambiguous @ 1st: developer in ['developer', 'achieve']
# ambiguous @ 1st: business in ['business', 'uniquely']
# ambiguous @ 1st: business in ['business', 'uniquely']
# ambiguous @ 1st: software in ['software', '</s>']
# keyword: startup, Business and Financial Ops
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: book in ['<s>', 'book']
# ambiguous @ 1st: news in ['news', 'simplify']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: educator in ['marketing', 'educator']
# ambiguous @ 1st: information in ['information', 'technology']
# ambiguous @ 1st: machine in ['machine', '</s>']
# ambiguous @ 1st: cook in ['cook', '</s>']
# ambiguous @ 1st: business in ['business', 'owner']
# unambiguous: turn in ['<s>', 'turn']
# ambiguous @ 1st: include in ['include', '</s>']
# unambiguous: customer in ['<s>', 'customer']
# ambiguous @ 1st: special in ['special', 'creation']
# ambiguous @ 1st: information in ['information', 'security']
# unambiguous: market in ['<s>', 'market']
# ambiguous @ 1st: art in ['art', '</s>']
# keyword: ai, Computer and Mathematical
# ambiguous @ 1st: research in ['research', 'instr']
# ambiguous @ 1st: marketing in ['marketing', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: security in ['security', 'comms']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: management in ['management', 'consultancy']
# ambiguous @ 1st: account in ['account', '</s>']
# keyword: ai, Computer and Mathematical
# keyword: technology, Computer and Mathematical
# ambiguous @ 1st: signal in ['signal', 'subscribe']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: advisor in ['advisor', '</s>']
# ambiguous @ 1st: guide in ['guide', 'disruptive']
# ambiguous @ 1st: sport in ['sport', '</s>']
# ambiguous @ 1st: security in ['security', '</s>']
# unambiguous: head in ['<s>', 'head']
# ambiguous @ 1st: commercial in ['commercial', 'intelligence']
# ambiguous @ 1st: account in ['account', '</s>']
# ambiguous @ 1st: commercial in ['commercial', 'intelligence']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: trainer in ['trainer', '</s>']
# unambiguous: process in ['win', 'process']
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: information in ['information', '</s>']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: first in ['first', 'print']
# ambiguous @ 1st: study in ['study', 'english']
# ambiguous @ 1st: study in ['study', 'english']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: business in ['business', 'cyber']
# ambiguous @ 1st: support in ['support', 'eo']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: maker in ['maker', '</s>']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: developer in ['developer', '</s>']
# ambiguous @ 1st: web in ['web', '</s>']
# ambiguous @ 1st: tool in ['tool', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 2nd: scientist in ['computer', 'scientist']
# unambiguous: part in ['<s>', 'part']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# unambiguous: official in ['<s>', 'official']
# unambiguous: part in ['<s>', 'part']
# unambiguous: still in ['<s>', 'still']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 2nd: developer in ['software', 'developer']
# unambiguous: part in ['<s>', 'part']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: healthcare in ['healthcare', '</s>']
# ambiguous @ 1st: community in ['community', '</s>']
# unambiguous: project in ['<s>', 'project']
# unambiguous: musician in ['<s>', 'musician']
# unambiguous: cardiovascular in ['<s>', 'cardiovascular']
# unambiguous: expert in ['cybersecurity', 'expert']
# unambiguous: new in ['<s>', 'new']
# unambiguous: expert in ['cybersecurity', 'expert']
# unambiguous: expert in ['cybersecurity', 'expert']
# ambiguous @ 1st: software in ['software', '</s>']
# ambiguous @ 1st: move in ['move', '</s>']
# unambiguous: work in ['architect', 'work']
# ambiguous @ 1st: human in ['human', '</s>']
# ambiguous @ 2nd: science in ['computer', 'science']
# unambiguous: work in ['<s>', 'work']
# ambiguous @ 1st: news in ['news', 'since']
# ambiguous @ 1st: private in ['private', 'account']
# unambiguous: new in ['<s>', 'new']
# ambiguous @ 2nd: scientist in ['computer', 'scientist']
# ambiguous @ 1st: development in ['development', '</s>']
# ambiguous @ 2nd: scientist in ['research', 'scientist']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: account in ['account', '</s>']
# unambiguous: photographer in ['professional', 'photographer']
# ambiguous @ 1st: first in ['first', 'global']
# unambiguous: reader in ['<s>', 'reader']
# ambiguous @ 1st: business in ['business', '</s>']
# unambiguous: group in ['prospitalia', 'group']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: home in ['home', '</s>']
# unambiguous: official in ['<s>', 'official']
# unambiguous: project in ['news', 'project']
# unambiguous: word in ['<s>', 'word']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: community in ['community', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: analyst in ['analyst', '</s>']
# ambiguous @ 1st: personal in ['personal', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: official in ['<s>', 'official']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: digital in ['<s>', 'digital']
# ambiguous @ 1st: tank in ['tank', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: art in ['art', '</s>']
# unambiguous: self in ['future', 'self']
# ambiguous @ 1st: trainer in ['trainer', '</s>']
# ambiguous @ 1st: social in ['social', 'commentator']
# keyword: blockchain, Computer and Mathematical
# unambiguous: good in ['<s>', 'good']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: water in ['water', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: business in ['business', '</s>']
# ambiguous @ 1st: executive in ['executive', '</s>']
# unambiguous: expert in ['<s>', 'expert']
# unambiguous: project in ['<s>', 'project']
# ambiguous @ 1st: human in ['human', 'symbiosis']
# unambiguous: justice in ['<s>', 'justice']
# ambiguous @ 1st: news in ['news', '</s>']
# ambiguous @ 1st: news in ['news', '</s>']
# unambiguous: game in ['<s>', 'game']
# unambiguous: policy in ['<s>', 'policy']
# ambiguous @ 2nd: science in ['computer', 'science']
# unambiguous: digital in ['<s>', 'digital']
# unambiguous: head in ['<s>', 'head']
# unambiguous: official in ['<s>', 'official']
# ambiguous @ 1st: software in ['software', '</s>']

# %%
nan_count  = data['occupation'].isna().sum()
print('Total count:', data.shape[0], 'NAN count:',nan_count)
data.to_csv(Path(data_dir, 'final_fear_occupation_datset.csv'), index=False)
# Out:
# Total count: 9941 NAN count: 2543

# %%
import matplotlib.pyplot as plt
data_dir = "/content/drive/MyDrive/SMM"
fear_df = pd.read_csv(Path(data_dir, 'final_fear_occupation_datset.csv'), encoding='unicode_escape',)

fear_only_df = fear_df[fear_df["fear?"] == 1]
fear_counts = fear_only_df['occupation'].value_counts()

# others_count = occupation_counts[occupation_counts < 10].sum()
# occupation_counts = occupation_counts[occupation_counts >= 10]
# occupation_counts['Others'] = others_count
ax = fear_counts.sort_values(ascending=True).plot(kind='barh', xlabel='Occupation', ylabel='Normalized Fear Frequency')
ax.set_title('Concern Frequency by Occupation')
# Out:
# Text(0.5, 1.0, 'Concern Frequency by Occupation')

# %%
total_fear_counts = fear_df['occupation'].value_counts()
normalized_fear_counts = fear_counts / total_fear_counts
ax = normalized_fear_counts.sort_values(ascending=True).plot(kind='barh', xlabel='Occupation', ylabel='Normalized Fear Frequency')
ax.set_title('Normalized Concern Frequency by Occupation')
# Out:
# Text(0.5, 1.0, 'Normalized Concern Frequency by Occupation')

# %%
data_dir = "/content/drive/MyDrive/SMM"
toxic_df = pd.read_csv(Path(data_dir, 'final_toxic_occupation_datset.csv'), encoding='unicode_escape',)

toxic_only_df = toxic_df[(toxic_df["toxic"] == 1) | (toxic_df["severe_toxic"] == 1) | (toxic_df["obscene"] == 1) | (toxic_df["threat"] == 1) | (toxic_df["insult"] == 1) | (toxic_df["identity_hate"] == 1)]
toxic_ones_count = toxic_only_df['occupation'].value_counts()
ax = toxic_ones_count.sort_values(ascending=True).plot(kind='barh', xlabel='Occupation', ylabel='Toxicity Frequency')
ax.set_title('Toxicity Frequency by Occupation')
# Out:
# Text(0.5, 1.0, 'Toxicity Frequency by Occupation')

# %%
total_toxic_counts = toxic_df['occupation'].value_counts()
normalized_toxic_counts = toxic_ones_count / total_toxic_counts
ax = normalized_fear_counts.sort_values(ascending=True).plot(kind='barh', xlabel='Occupation', ylabel='Normalized Toxicity Frequency')
ax.set_title('Normalized Toxicity Frequency by Occupation')
# Out:
# Text(0.5, 1.0, 'Normalized Toxicity Frequency by Occupation')
